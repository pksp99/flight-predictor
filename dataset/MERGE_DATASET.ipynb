# %%
import pandas as pd

# Define list of file paths
bts_files = ['JAN-2023.csv', 'FEB-2023.csv', 'MARCH-2023.csv','APRIL-2023.csv','MAY-2023.csv','JUNE-2023.csv']

# Concatenate multiple CSV files into a single DataFrame
flight_data_set = pd.concat([pd.read_csv(f) for f in bts_files])

# Display the first few rows of the concatenated DataFrame
flight_data_set.head()
# Out:
#    MONTH  DAY_OF_WEEK      FL_DATE MKT_UNIQUE_CARRIER  MKT_CARRIER_FL_NUM  \
# 0      1            1  1/2/23 0:00                 AA                   1
# 1      1            1  1/2/23 0:00                 AA                  10
# 2      1            1  1/2/23 0:00                 AA                1002
# 3      1            1  1/2/23 0:00                 AA                1002
# 4      1            1  1/2/23 0:00                 AA                1004
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  ...  \
# 0                AA                  1    JFK  LAX           730  ...
# 1                AA                 10    LAX  JFK          2208  ...
# 2                AA               1002    DCA  ORD          1215  ...
# 3                AA               1002    ORD  DCA           815  ...
# 4                AA               1004    BOS  CLT           644  ...
#
#    ARR_DELAY  CANCELLED  DIVERTED  DUP  CRS_ELAPSED_TIME DISTANCE  \
# ...

# %%
flight_data_set_filtered = flight_data_set[(flight_data_set['ORIGIN'].isin(['ORD', 'JFK', 'MCO'])) 
                                                & (flight_data_set['DEST'] == 'SYR') 
                                                    & (flight_data_set['MKT_UNIQUE_CARRIER'].isin(['AA','B6','DL','UA','WN']))]

print(set(flight_data_set_filtered['ORIGIN']))
print(set(flight_data_set_filtered['DEST']))
print(set(flight_data_set_filtered['MKT_UNIQUE_CARRIER']))
# Out:
# {'ORD', 'MCO', 'JFK'}
# {'SYR'}
# {'AA', 'WN', 'UA', 'DL', 'B6'}

# %%
flight_data_set_filtered.head()
# Out:
#       MONTH  DAY_OF_WEEK      FL_DATE MKT_UNIQUE_CARRIER  MKT_CARRIER_FL_NUM  \
# 2401      1            1  1/2/23 0:00                 AA                3392
# 2526      1            1  1/2/23 0:00                 AA                3518
# 5875      1            1  1/2/23 0:00                 B6                 116
# 6255      1            1  1/2/23 0:00                 B6                2516
# 6481      1            1  1/2/23 0:00                 B6                 656
#
#      OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  ...  \
# 2401                MQ               3392    ORD  SYR          1733  ...
# 2526                MQ               3518    ORD  SYR          1305  ...
# 5875                B6                116    JFK  SYR          1335  ...
# 6255                B6               2516    JFK  SYR          2230  ...
# 6481                B6                656    MCO  SYR          1545  ...
#
# ...

# %%
flight_data_set_filtered.shape[0]
# Out:
# 1860

# %%
# Define the file path where you want to save the filtered data
output_file_path = 'filtered_flight_data.csv'

# Save the filtered data to a CSV file
flight_data_set_filtered.to_csv(output_file_path, index=False)

print("Filtered data has been saved to:", output_file_path)
# Out:
# Filtered data has been saved to: filtered_flight_data.csv
